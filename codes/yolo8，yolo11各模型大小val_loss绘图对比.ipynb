# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
yolo11m = pd.read_csv(filepath_or_buffer = "C:\\Users\\Chenfei\\ultralytics\\runs\\detect\\train16-yolo11m\\results.csv")

# %%
yolo11m
# Out:
#     epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1    28.2135         3.29912         4.26876         4.09486
# 1       2    55.1485         2.98575         3.80032         3.50221
# 2       3    81.8461         2.78982         3.53310         3.21103
# 3       4   108.4600         2.73611         3.44518         3.11107
# 4       5   135.3860         2.66712         3.36396         3.04173
# ..    ...        ...             ...             ...             ...
# 95     96  2601.6000         1.39609         1.13303         1.73667
# 96     97  2628.5900         1.37813         1.11422         1.71337
# 97     98  2655.3200         1.39177         1.12267         1.72649
# 98     99  2682.2000         1.37051         1.09378         1.70582
# 99    100  2708.8100         1.35597         1.09629         1.69165
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.00171            0.18464           0.00220
# ...

# %%
yolo11m_val_cls_loss = yolo11m.loc[10:, "val/cls_loss"].to_numpy()

yolo11m_val_box_loss = yolo11m.loc[10:, "val/box_loss"].to_numpy()

yolo11m_val_dfl_loss = yolo11m.loc[10:, "val/dfl_loss"].to_numpy()

# %%
yolo11s = pd.read_csv(filepath_or_buffer = "C:\\Users\\Chenfei\\ultralytics\\runs\\detect\\train16-yolo11s\\results.csv")

# %%
yolo11s_val_cls_loss = yolo11s.loc[10:, "val/cls_loss"].to_numpy()

yolo11s_val_box_loss = yolo11s.loc[10:, "val/box_loss"].to_numpy()

yolo11s_val_dfl_loss = yolo11s.loc[10:, "val/dfl_loss"].to_numpy()

# %%
yolo11n = pd.read_csv(filepath_or_buffer = "C:\\Users\\Chenfei\\ultralytics\\runs\\detect\\train16-yolo11n\\results.csv")

# %%
yolo11n_val_cls_loss = yolo11n.loc[10:, "val/cls_loss"].to_numpy()

yolo11n_val_box_loss = yolo11n.loc[10:, "val/box_loss"].to_numpy()

yolo11n_val_dfl_loss = yolo11n.loc[10:, "val/dfl_loss"].to_numpy()

# %%
yolov8m = pd.read_csv(filepath_or_buffer = "C:\\Users\\Chenfei\\ultralytics\\runs\\detect\\train16-yolov8m\\results.csv")

# %%
yolov8m_val_cls_loss = yolov8m.loc[10:, "val/cls_loss"].to_numpy()

yolov8m_val_box_loss = yolov8m.loc[10:, "val/box_loss"].to_numpy()

yolov8m_val_dfl_loss = yolov8m.loc[10:, "val/dfl_loss"].to_numpy()

# %%
yolov8s = pd.read_csv(filepath_or_buffer = "C:\\Users\\Chenfei\\ultralytics\\runs\\detect\\train16-yolov8s\\results.csv")

# %%
yolov8s_val_cls_loss = yolov8s.loc[10:, "val/cls_loss"].to_numpy()

yolov8s_val_box_loss = yolov8s.loc[10:, "val/box_loss"].to_numpy()

yolov8s_val_dfl_loss = yolov8s.loc[10:, "val/dfl_loss"].to_numpy()

# %%
yolov8n = pd.read_csv(filepath_or_buffer = "C:\\Users\\Chenfei\\ultralytics\\runs\\detect\\train16-yolov8n\\results.csv")

# %%
yolov8n_val_cls_loss = yolov8n.loc[10:, "val/cls_loss"].to_numpy()

yolov8n_val_box_loss = yolov8n.loc[10:, "val/box_loss"].to_numpy()

yolov8n_val_dfl_loss = yolov8n.loc[10:, "val/dfl_loss"].to_numpy()

# %%
x = np.linspace(start = 11, stop = 100, num = 90)

# %%
plt.plot(x, yolo11m_val_cls_loss, color = "red", label = "yolo11m")
plt.plot(x, yolo11s_val_cls_loss, color = "orange", label = "yolo11s")
plt.plot(x, yolo11n_val_cls_loss, color = "magenta", label = "yolo11n")
plt.plot(x, yolov8m_val_cls_loss, color = "royalblue", label = "yolov8m")
plt.plot(x, yolov8s_val_cls_loss, color = "cyan", label = "yolov8s")
plt.plot(x, yolov8n_val_cls_loss, color = "green", label = "yolov8n")
plt.title("yolo_val_cls_loss")
plt.xlabel("epoch")
plt.legend()
plt.savefig("yolo_val_cls_loss.png")

# %%
plt.plot(x, yolo11m_val_box_loss, color = "red", label = "yolo11m")
plt.plot(x, yolo11s_val_box_loss, color = "orange", label = "yolo11s")
plt.plot(x, yolo11n_val_box_loss, color = "magenta", label = "yolo11n")
plt.plot(x, yolov8m_val_box_loss, color = "royalblue", label = "yolov8m")
plt.plot(x, yolov8s_val_box_loss, color = "cyan", label = "yolov8s")
plt.plot(x, yolov8n_val_box_loss, color = "green", label = "yolov8n")
plt.title("yolo_val_box_loss")
plt.xlabel("epoch")
plt.legend()
plt.savefig("yolo_val_box_loss.png")

# %%
plt.plot(x, yolo11m_val_dfl_loss, color = "red", label = "yolo11m")
plt.plot(x, yolo11s_val_dfl_loss, color = "orange", label = "yolo11s")
plt.plot(x, yolo11n_val_dfl_loss, color = "magenta", label = "yolo11n")
plt.plot(x, yolov8m_val_dfl_loss, color = "royalblue", label = "yolov8m")
plt.plot(x, yolov8s_val_dfl_loss, color = "cyan", label = "yolov8s")
plt.plot(x, yolov8n_val_dfl_loss, color = "green", label = "yolov8n")
plt.title("yolo_val_dfl_loss")
plt.xlabel("epoch")
plt.legend()
plt.savefig("yolo_val_dfl_loss.png")
