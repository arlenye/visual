# %%
from ultralytics import YOLO

# %%
import os

# %%
os.environ["KMP_DUPLICATE_LIB"] = "True"

# %%
model = YOLO("best.pt")

# %%
if __name__ == "__main__":
    results = model.predict(source = "u=3645719502,708523190&fm=193.jpg")
# Out:
# image 1/1 C:\Users\Chenfei\codes\u=3645719502,708523190&fm=193.jpg: 448x640 1 smoke, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 94.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
len(results[0])
# Out:
# 1

# %%
img = results[0].plot()

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(X = img[:,:,::-1])
plt.savefig("result.jpg")
