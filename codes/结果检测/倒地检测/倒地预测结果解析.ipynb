# %%
from ultralytics import YOLO

# %%
import os

# %%
os.environ["KMP_DUPLICATE_LIB"] = "True"

# %%
model = YOLO("best.pt")

# %%
if __name__ == "__main__":
    results = model.predict(source = "iOdhPYdbnu_small.jpg")
# Out:
# image 1/1 C:\Users\Chenfei\codes\\iOdhPYdbnu_small.jpg: 448x640 1 fall, 26.1ms
# Speed: 3.2ms preprocess, 26.1ms inference, 110.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
len(results[0])
# Out:
# 1

# %%
img = results[0].plot()

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(X = img[:,:,::-1])
plt.savefig("result.jpg")
